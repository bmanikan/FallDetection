# %% [markdown]
# <a href="https://colab.research.google.com/github/bmanikan/FallDetection/blob/main/Code%20notebooks/FallDetectionWandB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Note: This Notebook implements the algorithms and architectures for the falldetection problem using tensorflow and is similar to FallDetection_TF.ipynb. The only difference is that the log file is now documented in Weights and Biases website (wandb.com) for interactive visualization.**

# %% [markdown]
# ## Logger

# %%
import datetime
import time
import logging
import sys

def set_logger():
  logging.basicConfig(level=logging.INFO)
  logger_t = logging.getLogger('withoutlevel')
  logger = logging.getLogger('withlevel')

  f_handler = logging.FileHandler('Falldetection.log')
  f_handler_t = logging.FileHandler('Falldetection.log')

  f_format = logging.Formatter('%(levelname)s - %(message)s')
  f_format_t = logging.Formatter('%(message)s')

  f_handler.setFormatter(f_format)
  f_handler_t.setFormatter(f_format_t)

  logger.addHandler(f_handler)
  logger_t.addHandler(f_handler_t)
  return logger, logger_t

# %%
import datetime
import time
t_set = lambda: datetime.datetime.now().astimezone()
t_diff = lambda t: str(t_set() - t)
w_diff = lambda t: (t_set() - t).total_seconds()
t_stamp = lambda t=None: str(t) if t else str(t_set())
t = t_set()
time.sleep(5)
t_diff(t)
# Out:
# '0:00:05.005365'

# %%
import logging
import sys

#logger without time
logging.basicConfig(level=logging.INFO)
logger_t = logging.getLogger('withoutlevel')
logger = logging.getLogger('withlevel')

f_handler = logging.FileHandler('Falldetection.log')
f_handler_t = logging.FileHandler('Falldetection.log')

f_format = logging.Formatter('%(levelname)s - %(message)s')
f_format_t = logging.Formatter('%(message)s')

f_handler.setFormatter(f_format)
f_handler_t.setFormatter(f_format_t)

logger.addHandler(f_handler)
logger_t.addHandler(f_handler_t)

# %%
import platform
platform.uname()
for det in platform.uname():
  logger_t.info(str(det))
# Out:
# INFO:withoutlevel:Linux
# INFO:withoutlevel:11f15fe0b98a
# INFO:withoutlevel:5.4.104+
# INFO:withoutlevel:#1 SMP Sat Jun 5 09:50:34 PDT 2021
# INFO:withoutlevel:x86_64
# INFO:withoutlevel:x86_64

# %%
logger_t.info('='*100)
logger_t.info("\nFalldetection project")
# Out:
# INFO:withoutlevel:====================================================================================================
# INFO:withoutlevel:
# Falldetection project

# %% [markdown]
# ## config

# %%
# %%capture
# !pip install wandb

# %%
import tensorflow as tf
import numpy as np
import random
import os

#Set seed value
seed_value = 43

os.environ['PYTHONHASHSEED'] = str(seed_value)

random.seed(seed_value)

#numpy seed
np.random.seed(seed_value)

#Tf seed
tf.random.set_seed(seed_value)

#Configure new global tensorflow session
from tensorflow.compat.v1.keras import backend as k
session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads = 1,
    inter_op_parallelism_threads = 1
)

sess = tf.compat.v1.Session(graph = tf.compat.v1.get_default_graph(), config = session_conf)
k.set_session(sess)

# %%
import wandb 
wandb.login()
wandb.init(project="fall_detection",
          config={
              'frameCount'    :50,
              'data_size'     :120,
              'dataset'       :'urfd',
              'epochs'        :15,
              'seed_value'    :43,
              'split'         :0.8,
              'batch_size'    :32,
              'activation'    :'relu',
              'optimizer'     :'adam',
              'loss_fn'       :'binarycrossentropy',
              'dropout_rate'  :0.5
          })
cfg = wandb.config
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: manikandan (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">rural-resonance-27</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/manikandan/fall_detection" target="_blank">https://wandb.ai/manikandan/fall_detection</a><br/>
#                 Run page: <a href="https://wandb.ai/manikandan/fall_detection/runs/1fre7iiu" target="_blank">https://wandb.ai/manikandan/fall_detection/runs/1fre7iiu</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210729_133600-1fre7iiu</code><br/><br/>

# %%
logger.info(f"The analysis with dataset {cfg.dataset} and frame count {cfg.frameCount} and size of the data is {cfg.data_size}.")
# Out:
# INFO:withlevel:The analysis with dataset urfd and frame count 50 and size of the data is 120.

# %% [markdown]
# ## Download dataset

# %%
import urllib.request as urlreq
from zipfile import ZipFile
import shutil
import os
from tqdm.notebook import tqdm
import socket
socket.setdefaulttimeout(20)

logger_t.info(f'{"="*100} \n\nSTEP 1: Download dataset into the system')

def safedirs(path):
  if not os.path.exists(path):
    os.makedirs(path)

def extract_zip(src, dest, map):
    '''
    Extracts the contents downloaded from the URL
    '''
    zip_ref = ZipFile(src,'r')
    for name in zip_ref.namelist():
      ext = name.split('.')[-1]
      if ext in map.keys():
        dest = os.path.join(dest,map[ext])
        break
    zip_ref.extractall(dest)
    logger_t.info(f'... into {dest}')
    zip_ref.close()

def cleanup(dataPath):
  '''
  clean the temp files
  '''
  for folder in os.listdir(dataPath):
    if folder == 'temp':
      cleanup_path = os.path.join(dataPath,'temp')
      shutil.rmtree(cleanup_path)
      break
  return

def download(url, root):
  '''
  downloads the file from the url
  and put it in desired folder
  '''
  
  map = {'csv':'csv', 'zip':'temp', 'png':'frame', 'jpg':'frame', 'mp4':'video', 'avi':'video'}
  ext = url.split('.')[-1] 
  # raise if the url is of not file type
  assert ext in map.keys(), "invalid url"
  name = url.split('/')[-1]
  filePath = os.path.join(root, map[ext])
  safedirs(filePath)
  filename = os.path.join(filePath,name)
  if os.path.exists(filename):
    return 
  logger_t.info(f"Downloading data files from URL:{url}")
  
  while True:
    try:
      urlreq.urlretrieve(url, filename)
      #if the file downloaded is zip file then extract original files
      if ext == 'zip':
        extract_zip(filename,root,map)
    except Exception as e:
      print(f'error {e} at {url}')
      continue
    break
    
  
    

def urfd(dataPath,num=40,clean=False):
  '''
  download the files from the URFD data url
  dataPath: destination path
  num: number of files to download
  clean: whether to clean the temp files
  '''
  #csv file url's
  csv = ['http://fenix.univ.rzeszow.pl/~mkepski/ds/data/urfall-cam0-adls.csv',
         'http://fenix.univ.rzeszow.pl/~mkepski/ds/data/urfall-cam0-falls.csv']
  #download csv files
  for f in csv:
    t = t_set()
    download(f,dataPath)
    logger.info(f'Elapsed time for downloading and extracting the file is {t_diff(t)}.\n')
    wandb.log({'download':{'time':w_diff(t)}})
  #download frame zip files from the project website
  for n in tqdm(range(1,num+1)):
    # Add zeros to adapt files in Website
    if n < 10:
      n = '0'+str(n)
    #only 31 Fall sequences available
    if int(n)<31:
      t = t_set()
      fall_url = f'http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-{n}-cam0-rgb.zip'
      download(fall_url,datapath)
      logger.info(f'Elapsed time for downloading and extracting the file is {t_diff(t)}\n')
      wandb.log({'download':{'time':w_diff(t)}})
    t=t_set()
    adl_url = f'http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-{n}-cam0-rgb.zip'
    download(adl_url,dataPath)
    logger.info(f'Elapsed time for downloading and extracting the file is {t_diff(t)}\n')
    wandb.log({'download':{'time':w_diff(t)}})
    
    if n == num-1 and clean:
      cleanup(dataPath)




root = os.getcwd()
datapath = root + '/dataset/urfd'
logger.info(f'Dateset is downloaded in path {datapath}')
t= t_set()
urfd(datapath) 
logger.info(f'Total time for downloading and extracting entire dataset is {t_diff(t)}\n {"="*200}')
wandb.summary['Download_TotalTime'] = w_diff(t)
# Out:
# INFO:withoutlevel:====================================================================================================
#
# STEP 1: Download dataset into the system
# INFO:withlevel:Dateset is downloaded in path /content/dataset/urfd
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/urfall-cam0-adls.csv
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:01.120561.
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/urfall-cam0-falls.csv
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:00.822965.
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-01-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.165348
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-01-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.974817
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-02-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:03.443290
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-02-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.635295
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-03-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.690408
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-03-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.735441
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-04-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:03.213318
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-04-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.934429
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-05-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.309565
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-05-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.713103
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-06-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:03.184028
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-06-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.889037
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-07-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.341551
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-07-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.678009
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-08-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:03.016152
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-08-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.554046
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-09-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.910141
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-09-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.974593
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-10-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:03.651989
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-10-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:09.037097
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-11-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:03.989547
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-11-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:08.643870
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-12-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:03.419927
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-12-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.006080
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-13-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.896804
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-13-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.606009
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-14-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.510309
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-14-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.675898
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-15-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.492496
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-15-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.733076
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-16-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.239592
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-16-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.973009
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-17-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.903925
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-17-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.555723
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-18-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.483683
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-18-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.906135
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-19-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.979033
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-19-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.203908
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-20-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.991707
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-20-cam0-rgb.zip
# error timed out at http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-20-cam0-rgb.zip
# error <urlopen error timed out> at http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-20-cam0-rgb.zip
# error <urlopen error timed out> at http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-20-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:01:18.836966
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-21-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.111349
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-21-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:08.091012
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-22-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.201704
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-22-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.030247
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-23-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.447876
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-23-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.477421
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-24-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.190914
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-24-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.011190
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-25-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.795699
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-25-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.500801
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-26-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.401177
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-26-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.612831
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-27-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.815314
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-27-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.646335
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-28-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.314444
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-28-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.325931
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-29-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.929647
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-29-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.823488
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-30-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:02.442858
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-30-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.784176
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-31-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.897591
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-32-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.998696
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-33-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.518733
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-34-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:04.505314
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-35-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.785041
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-36-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.923238
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-37-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:07.127300
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-38-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.793733
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-39-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:05.627692
#
# INFO:withoutlevel:Downloading data files from URL:http://fenix.univ.rzeszow.pl/~mkepski/ds/data/adl-40-cam0-rgb.zip
# INFO:withoutlevel:... into /content/dataset/urfd/frame
# INFO:withlevel:Elapsed time for downloading and extracting the file is 0:00:06.649993
#
# INFO:withlevel:Total time for downloading and extracting entire dataset is 0:06:44.569934
#  ========================================================================================================================================================================================================

# %% [markdown]
# ## Label enrichment

# %%
import pandas as pd
import os

logger_t.info(f'{"="*200} \n\nSTEP 2: Assign labels to each frames')

def assign_label(df,root,filenames):
  for filename in filenames:
    #processed files contain '_' hence we can omit those
    if '_' in filename:
      continue
    #get the extension from the file
    ext = filename.split('.')[-1]
    split_array = filename.split('.')[0].split('-')
    #extract id and frame
    file_id,frame_id = '-'.join(split_array[:2]), split_array[-1]
    #adl files doesnt contain falls hence assigning label 0 to all files
    if 'adl' in file_id:
      label = 0
    else:
      #check the label in dataframe for id and frame
      df_label = int(df[(df[0] == file_id) & (df[1] == int(frame_id))][2])
      label = 1 if df_label == 1 else 0
    #Rename the files
    name = f'{file_id}_{frame_id}_{label}.{ext}'
    new_path = os.path.join(root, name)
    old_path = os.path.join(root,filename)
    os.rename(old_path,new_path)
    # create a entry in the dataframe for new path of the frame file
    df.loc[(df[0] == file_id) & (df[1] == int(frame_id)), 'path'] = new_path
    df.loc[(df[0] == file_id) & (df[1] == int(frame_id)), 2] = label


def enrich_labels(df,dataPath,folder=True):
  '''
  Embed labels into the data filenames
  df: data frame consisting of details on labels
  datapath: the path of the folder containing frames
  folder: indicates the structure of the data
  '''
  if folder:
    root, dirs, _ = next(os.walk(dataPath))
    dir_array = [os.path.join(root,dir) for dir in dirs]
    for path in dir_array:
      root, _, files = next(os.walk(path))
      assign_label(df,root,files)
  else:
    root, _, files = next(os.walk(dataPath))
    assign_label(df, root, files)
# Out:
# INFO:withoutlevel:========================================================================================================================================================================================================
#
# STEP 2: Assign labels to each frames

# %%
# create dataframe for further processing using the CSV file data
csv = root + '/dataset/urfd/csv'
df_fall = pd.read_csv('/content/dataset/urfd/csv/urfall-cam0-falls.csv',header=None)
df_adl = pd.read_csv('/content/dataset/urfd/csv/urfall-cam0-adls.csv',header=None)
dfs = pd.concat([df_fall,df_adl],ignore_index=True)
dfs = dfs[[0,1,2]]
dfs['path'] = None
logger_t.info(f"Enrich labels into the filenames extractend from the CSV files")
t = t_set()
enrich_labels(dfs,'/content/dataset/urfd/frame')
logger.info(f'Elapsed time for modifying filenames: {t_diff(t)}s.')
wandb.summary["ModifyFileNames_totaltime"] = w_diff(t)
# Out:
# INFO:withoutlevel:Enrich labels into the filenames extractend from the CSV files
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:withlevel:Elapsed time for modifying filenames: 0:00:56.736262s.

# %% [markdown]
# ## Create Subset

# %%
import numpy as np
import os
import shutil
from tqdm.notebook import tqdm
import torch
import random
from torch.utils.data import random_split


def safedirs(path):
  if not os.path.exists(path):
    os.makedirs(path)

def createDataset(df,dataPath,destPath,ids,clip_len=50,size=60):
  random.seed(cfg.seed_value)
  logger.info(f'Seed value is {cfg.seed_value}')
  assert size % 60 == 0, "Size should be in the multiple of 60"
  assert type(ids) == list, "expecting a list of strings"
  data_files = {i:[] for i in ids}
  for root,dir,files in os.walk(dataPath):
    for f in files:
      id = f.split('_')[0]
      if id in ids:
        data_files[id].append(os.path.join(root,f))
  for subset in range(size//60):
    t = t_set()
    for idx in range(len(list(data_files.keys()))):
      path = sorted(data_files[list(data_files.keys())[idx]])
      topic = (list(data_files.keys())[idx])
      while True:
        root_path = os.path.join(destPath, topic.split('-')[0], topic+'_'+str(subset))
        safedirs(root_path)
        rand_n = random.randint(0,len(path)-clip_len)
        frame_path = path[rand_n : rand_n+clip_len]
        labels = []
        for fp in frame_path:
          shutil.copy(fp, os.path.join(root_path, os.path.basename(fp)))
          #frame is the datapath with label at the end of the filename
          labels.append(int(fp.split('.')[0][-1]))
        if topic.split('-')[0] == 'adl':
          break
        elif topic.split('-')[0] == 'fall' and labels.count(1) > 4:
          break
        shutil.rmtree(root_path)
    logger.info(f'time elapsed for each subset {subset} is {t_diff(t)}')

# %%
from torch.utils.data import random_split
#120 image dataset
#shutil.rmtree('/content/subset')
logger_t.info(f'{"="*100} \n\nSTEP 3: Create subset of 60/120/180 files of 50 Frames each from the Dataset')

logger.info(f'Size of the subset: {cfg.data_size}')
ids = dfs[0].unique()[:60]
train_size = int(cfg.split*len(ids))
val_size = int(cfg.split*(len(ids) - train_size))
test_size = len(ids) - (train_size + val_size)
train_ids,valid_ids,test_ids = random_split(ids,[train_size,val_size,test_size],generator=torch.Generator().manual_seed(1))
logger_t.info(f'train_size={train_size}\nvalidation_size={val_size}\ntest_size={test_size}')
wandb.summary['trainset_size'] = train_size
wandb.summary['validationset_size'] = val_size
wandb.summary['testset_size'] = test_size
logger_t.info(f'train_ids={train_ids}\nvalidation ids={valid_ids}\ntest_ids={test_ids}')

train_destPath = os.path.join(os.getcwd(),'subset/train')
valid_destPath = os.path.join(os.getcwd(),'subset/valid')
test_destPath = os.path.join(os.getcwd(),'subset/test')
logger_t.info(f'train path= {train_destPath}\nvalidation path= {valid_destPath}\nTest path= {test_destPath}')

t = t_set()
createDataset(dfs,'/content/dataset/urfd/frame', train_destPath, ids = list(train_ids), clip_len=cfg.frameCount, size=cfg.data_size)
logger.info(f"Time elapsed for creating Train subset is {t_diff(t)}")
wandb.summary['trainSubset_creationTime'] = w_diff(t)
t = t_set()
createDataset(dfs,'/content/dataset/urfd/frame', valid_destPath, ids = list(valid_ids), clip_len=cfg.frameCount, size=cfg.data_size)
logger.info(f"Time elapsed for creating Validation subset is {t_diff(t)}")
wandb.summary['valSubset_creationTime'] = w_diff(t)
t = t_set()
#createDataset(dfs,'/content/dataset/urfd/frame',test_destPath,ids = list(test_ids),size=size)
createDataset(dfs,'/content/dataset/urfd/frame', test_destPath, ids = list(ids), clip_len=cfg.frameCount, size=cfg.data_size)
logger.info(f"Time elapsed for creating Test subset is {t_diff(t)}")
wandb.summary['testSubset_creationTime'] = w_diff(t)
# Out:
# INFO:withoutlevel:====================================================================================================
#
# STEP 3: Create subset of 60/120/180 files of 50 Frames each from the Dataset
# INFO:withlevel:Size of the subset: 120
# INFO:withoutlevel:train_size=48
# validation_size=9
# test_size=3
# INFO:withoutlevel:train_ids=<torch.utils.data.dataset.Subset object at 0x7f7c810d1090>
# validation ids=<torch.utils.data.dataset.Subset object at 0x7f7c810d1850>
# test_ids=<torch.utils.data.dataset.Subset object at 0x7f7c810d1690>
# INFO:withoutlevel:train path= /content/subset/train
# validation path= /content/subset/valid
# Test path= /content/subset/test
# INFO:withlevel:Seed value is 43
# INFO:withlevel:time elapsed for each subset 0 is 0:00:09.349669
# INFO:withlevel:time elapsed for each subset 1 is 0:00:08.427887
# INFO:withlevel:Time elapsed for creating Train subset is 0:00:17.829298
# INFO:withlevel:Seed value is 43
# INFO:withlevel:time elapsed for each subset 0 is 0:00:01.692962
# INFO:withlevel:time elapsed for each subset 1 is 0:00:01.454045
# INFO:withlevel:Time elapsed for creating Validation subset is 0:00:03.198948
# INFO:withlevel:Seed value is 43
# INFO:withlevel:time elapsed for each subset 0 is 0:00:12.235437
# INFO:withlevel:time elapsed for each subset 1 is 0:00:15.148867
# INFO:withlevel:Time elapsed for creating Test subset is 0:00:27.449343

# %% [markdown]
# ## Embedding data

# %%
from collections import defaultdict
from skimage.metrics import structural_similarity
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time,os
from PIL import Image
import tensorflow as tf
from tensorflow.keras.layers.experimental import preprocessing


def person_detector(imageMatrix,label,mode,folder):
  '''
  Moving object detection by frame differencing
  input: torch tensor object of shape [batch,50,3,480,640] and labels array
  output: tuple of torch tensor [batch,1,224,224] and label object 
  '''
  info = ['adl','fall']
  bbox_path = os.path.join(os.getcwd(), 'boundingBox', mode, info[label], folder)
  logger_t.info(f'Working on creating ... {bbox_path} set')
  safedirs(bbox_path)
  temp_img = imageMatrix
  center_points = []
  for i in range(0,temp_img.shape[0] - 2):
    img1 = cv2.medianBlur(cv2.cvtColor(temp_img[i],cv2.COLOR_BGR2GRAY),5)
    img2 = cv2.medianBlur(cv2.cvtColor(temp_img[i+2],cv2.COLOR_BGR2GRAY),5)
    (score,diff) = structural_similarity(img1,img2,full=True)
    diff = (diff * 255).astype('uint8')
    thresh = cv2.threshold(diff, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
    dilate_frame = cv2.dilate(thresh, None, iterations=5)
    contours = cv2.findContours(dilate_frame.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    contours = contours[0] if len(contours) == 2 else contours[1] 
    val = np.argmax([cv2.contourArea(c) for c in contours])
    x,y,w,h = cv2.boundingRect(contours[val])
    cv2.rectangle(img1, (x, y), (x + w, y + h), (36,255,12), 2)
    path = os.path.join(bbox_path, f'image_{i}.jpg')
    cv2.imwrite(path, img1)
    center = (int((x+w)/2), int((y+h)/2))
    center_points.append(center)
  return center_points

def get_transform():
  transform = tf.keras.Sequential([
                                   preprocessing.Resizing(224,224),
                                   preprocessing.Normalization()
  ])
  return transform


def image_embedding(images,label,mode,filename):
  transform = get_transform()
  info = ['adl', 'fall']
  trajectory_path = os.path.join(os.getcwd(), 'trajectories', mode, info[label])
  safedirs(trajectory_path)
  logger_t.info(f'creating trajectory image at {trajectory_path}')
  bkg = np.zeros((480,640),np.uint8)
  t=t_set()
  points = person_detector(images,label,mode,filename) 
  logger.info(f'Elapsed time for Bounding box calculation is {t_diff(t)}')
  wandb.log({'boundingBox':{'time':w_diff(t)}})
  for p in range(len(points)-1):
    bkg = cv2.line(bkg,points[p],points[p+1],(255,0,0),5)
  bkg = transform(tf.expand_dims(bkg,2))
  path = os.path.join(trajectory_path, filename+'.jpg')
  cv2.imwrite(path, bkg.numpy())


def embedded_data(datapath):
  data_dict = defaultdict(list)
  for root,dir,files in os.walk(datapath):
      for f in files:
        frame_path = os.path.join(root,f)
        #print(root)
        folder = os.path.basename(root)
        data_dict[folder].append(frame_path)
  for key in list(data_dict.keys()):
    frames, labels = [], []
    for f in sorted(data_dict[key]):
      labels.append(int(f.split('.')[0][-1]))
      temp = f.split('/')
      mode = temp[3]
      filename = temp[5]
      img = cv2.cvtColor(cv2.imread(f),cv2.COLOR_BGR2RGB)
      frames.append(img)
    frames = np.stack(frames,axis=0)
    t=t_set()
    image_embedding(frames, np.max(labels), mode, filename)
    logger.info(f"Total time taken for {key} is {t_diff(t)}")
    wandb.log({'trajectory':{'time':w_diff(t)}})


logger_t.info(f'{"="*100} \n\nSTEP 4: Create Trajectory images\n')
t = t_set()
root = os.getcwd()
embedded_data(root + '/subset/train')
embedded_data(root + '/subset/valid')
embedded_data(root + '/subset/test')
logger.info(f'Total time taken to create trajectory images: {t_diff(t)}')
wandb.summary["Trajectory_totaltime"] = w_diff(t)
# Out:
# INFO:withoutlevel:====================================================================================================
#
# STEP 4: Create Trajectory images
#
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-05_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.649385
# INFO:withlevel:Total time taken for adl-05_0 is 0:00:02.965644
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-07_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.565487
# INFO:withlevel:Total time taken for adl-07_0 is 0:00:02.600258
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-04_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.611974
# INFO:withlevel:Total time taken for adl-04_1 is 0:00:02.644887
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-27_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.566125
# INFO:withlevel:Total time taken for adl-27_0 is 0:00:02.602247
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-29_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.573855
# INFO:withlevel:Total time taken for adl-29_0 is 0:00:02.611022
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-14_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.531048
# INFO:withlevel:Total time taken for adl-14_0 is 0:00:02.565257
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-16_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.554174
# INFO:withlevel:Total time taken for adl-16_0 is 0:00:02.590960
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-16_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.578043
# INFO:withlevel:Total time taken for adl-16_1 is 0:00:02.612225
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-10_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.557367
# INFO:withlevel:Total time taken for adl-10_1 is 0:00:02.592734
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-07_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.649171
# INFO:withlevel:Total time taken for adl-07_1 is 0:00:02.682138
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-27_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.480460
# INFO:withlevel:Total time taken for adl-27_1 is 0:00:02.511097
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-14_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.507895
# INFO:withlevel:Total time taken for adl-14_1 is 0:00:02.538479
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-15_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.505120
# INFO:withlevel:Total time taken for adl-15_0 is 0:00:02.544678
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-05_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.552856
# INFO:withlevel:Total time taken for adl-05_1 is 0:00:02.591999
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-08_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.561375
# INFO:withlevel:Total time taken for adl-08_1 is 0:00:02.605092
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-30_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.490606
# INFO:withlevel:Total time taken for adl-30_0 is 0:00:02.528622
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-11_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.568525
# INFO:withlevel:Total time taken for adl-11_0 is 0:00:02.607229
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-09_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.522438
# INFO:withlevel:Total time taken for adl-09_0 is 0:00:02.557392
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-26_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.532874
# INFO:withlevel:Total time taken for adl-26_0 is 0:00:02.565268
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-30_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.628768
# INFO:withlevel:Total time taken for adl-30_1 is 0:00:02.664795
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-19_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.558687
# INFO:withlevel:Total time taken for adl-19_1 is 0:00:02.596907
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-21_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.609656
# INFO:withlevel:Total time taken for adl-21_1 is 0:00:02.643909
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-04_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.620045
# INFO:withlevel:Total time taken for adl-04_0 is 0:00:02.659254
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-15_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.580026
# INFO:withlevel:Total time taken for adl-15_1 is 0:00:02.614936
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-28_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.489623
# INFO:withlevel:Total time taken for adl-28_1 is 0:00:02.526324
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-18_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.529173
# INFO:withlevel:Total time taken for adl-18_1 is 0:00:02.566532
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-19_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.523978
# INFO:withlevel:Total time taken for adl-19_0 is 0:00:02.561942
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-03_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.558533
# INFO:withlevel:Total time taken for adl-03_0 is 0:00:02.594996
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-18_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.536191
# INFO:withlevel:Total time taken for adl-18_0 is 0:00:02.571224
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-22_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.540361
# INFO:withlevel:Total time taken for adl-22_1 is 0:00:02.577459
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-22_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.542935
# INFO:withlevel:Total time taken for adl-22_0 is 0:00:02.580395
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-09_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.493768
# INFO:withlevel:Total time taken for adl-09_1 is 0:00:02.526940
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-06_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.578369
# INFO:withlevel:Total time taken for adl-06_0 is 0:00:02.613989
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-28_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.564868
# INFO:withlevel:Total time taken for adl-28_0 is 0:00:02.597963
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-08_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.565516
# INFO:withlevel:Total time taken for adl-08_0 is 0:00:02.597406
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-21_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.586179
# INFO:withlevel:Total time taken for adl-21_0 is 0:00:02.621394
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-29_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.479066
# INFO:withlevel:Total time taken for adl-29_1 is 0:00:02.515729
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-03_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.579442
# INFO:withlevel:Total time taken for adl-03_1 is 0:00:02.620164
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-11_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.547720
# INFO:withlevel:Total time taken for adl-11_1 is 0:00:02.585789
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-26_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.545729
# INFO:withlevel:Total time taken for adl-26_1 is 0:00:02.578274
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-10_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.578548
# INFO:withlevel:Total time taken for adl-10_0 is 0:00:02.611805
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/adl/adl-06_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.604479
# INFO:withlevel:Total time taken for adl-06_1 is 0:00:02.640259
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-20_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.566894
# INFO:withlevel:Total time taken for fall-20_1 is 0:00:02.604474
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-22_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.557303
# INFO:withlevel:Total time taken for fall-22_0 is 0:00:02.593503
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-24_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.605359
# INFO:withlevel:Total time taken for fall-24_0 is 0:00:02.643211
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-06_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.499374
# INFO:withlevel:Total time taken for fall-06_0 is 0:00:02.535173
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-13_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.545682
# INFO:withlevel:Total time taken for fall-13_1 is 0:00:02.578890
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-17_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.498097
# INFO:withlevel:Total time taken for fall-17_1 is 0:00:02.531551
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-27_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.508570
# INFO:withlevel:Total time taken for fall-27_0 is 0:00:02.543020
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-13_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.496329
# INFO:withlevel:Total time taken for fall-13_0 is 0:00:02.539507
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-15_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.485218
# INFO:withlevel:Total time taken for fall-15_1 is 0:00:02.519004
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-16_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.522160
# INFO:withlevel:Total time taken for fall-16_1 is 0:00:02.562795
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-23_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.522721
# INFO:withlevel:Total time taken for fall-23_1 is 0:00:02.558540
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-26_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.503258
# INFO:withlevel:Total time taken for fall-26_1 is 0:00:02.545479
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-25_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.564293
# INFO:withlevel:Total time taken for fall-25_0 is 0:00:02.602250
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-23_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.513512
# INFO:withlevel:Total time taken for fall-23_0 is 0:00:02.554578
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-30_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.544944
# INFO:withlevel:Total time taken for fall-30_1 is 0:00:02.580922
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-05_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.492960
# INFO:withlevel:Total time taken for fall-05_0 is 0:00:02.527209
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-21_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.550717
# INFO:withlevel:Total time taken for fall-21_1 is 0:00:02.589298
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-04_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.599596
# INFO:withlevel:Total time taken for fall-04_1 is 0:00:02.639002
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-29_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.497180
# INFO:withlevel:Total time taken for fall-29_1 is 0:00:02.536959
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-17_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.533931
# INFO:withlevel:Total time taken for fall-17_0 is 0:00:02.576185
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-18_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.496907
# INFO:withlevel:Total time taken for fall-18_1 is 0:00:02.539806
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-03_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.486341
# INFO:withlevel:Total time taken for fall-03_1 is 0:00:02.520267
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-29_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.503154
# INFO:withlevel:Total time taken for fall-29_0 is 0:00:02.542760
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-07_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.502760
# INFO:withlevel:Total time taken for fall-07_1 is 0:00:02.549523
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-07_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.519758
# INFO:withlevel:Total time taken for fall-07_0 is 0:00:02.555828
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-26_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.520692
# INFO:withlevel:Total time taken for fall-26_0 is 0:00:02.554673
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-06_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.511729
# INFO:withlevel:Total time taken for fall-06_1 is 0:00:02.548204
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-25_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.518094
# INFO:withlevel:Total time taken for fall-25_1 is 0:00:02.555348
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-27_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.466007
# INFO:withlevel:Total time taken for fall-27_1 is 0:00:02.499150
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-18_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.563428
# INFO:withlevel:Total time taken for fall-18_0 is 0:00:02.598655
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-22_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.497851
# INFO:withlevel:Total time taken for fall-22_1 is 0:00:02.538548
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-12_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.569003
# INFO:withlevel:Total time taken for fall-12_1 is 0:00:02.602873
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-11_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.568085
# INFO:withlevel:Total time taken for fall-11_0 is 0:00:02.638571
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-14_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.537959
# INFO:withlevel:Total time taken for fall-14_0 is 0:00:02.569726
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-03_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.561724
# INFO:withlevel:Total time taken for fall-03_0 is 0:00:02.597545
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-09_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.537725
# INFO:withlevel:Total time taken for fall-09_1 is 0:00:02.573447
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-11_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.597200
# INFO:withlevel:Total time taken for fall-11_1 is 0:00:02.639034
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-20_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.741031
# INFO:withlevel:Total time taken for fall-20_0 is 0:00:02.775111
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-08_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.602218
# INFO:withlevel:Total time taken for fall-08_0 is 0:00:02.636327
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-02_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.546071
# INFO:withlevel:Total time taken for fall-02_1 is 0:00:02.587613
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-08_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.521330
# INFO:withlevel:Total time taken for fall-08_1 is 0:00:02.553257
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-24_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.534202
# INFO:withlevel:Total time taken for fall-24_1 is 0:00:02.569642
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-30_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.480369
# INFO:withlevel:Total time taken for fall-30_0 is 0:00:02.511932
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-19_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.519824
# INFO:withlevel:Total time taken for fall-19_0 is 0:00:02.558894
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-02_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.532357
# INFO:withlevel:Total time taken for fall-02_0 is 0:00:02.567190
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-05_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.514165
# INFO:withlevel:Total time taken for fall-05_1 is 0:00:02.548966
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-19_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.536266
# INFO:withlevel:Total time taken for fall-19_1 is 0:00:02.570974
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-14_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.472995
# INFO:withlevel:Total time taken for fall-14_1 is 0:00:02.508782
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-04_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.559042
# INFO:withlevel:Total time taken for fall-04_0 is 0:00:02.591144
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-12_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.504135
# INFO:withlevel:Total time taken for fall-12_0 is 0:00:02.543924
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-21_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.560475
# INFO:withlevel:Total time taken for fall-21_0 is 0:00:02.594229
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-15_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.526089
# INFO:withlevel:Total time taken for fall-15_0 is 0:00:02.566081
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-16_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.526763
# INFO:withlevel:Total time taken for fall-16_0 is 0:00:02.561926
# INFO:withoutlevel:creating trajectory image at /content/trajectories/train/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/train/fall/fall-09_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.585546
# INFO:withlevel:Total time taken for fall-09_0 is 0:00:02.621694
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-23_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.518860
# INFO:withlevel:Total time taken for adl-23_1 is 0:00:02.552596
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-25_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.505241
# INFO:withlevel:Total time taken for adl-25_1 is 0:00:02.548986
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-25_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.592395
# INFO:withlevel:Total time taken for adl-25_0 is 0:00:02.628884
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-13_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.517912
# INFO:withlevel:Total time taken for adl-13_0 is 0:00:02.550453
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-13_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.521162
# INFO:withlevel:Total time taken for adl-13_1 is 0:00:02.553732
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-17_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.546740
# INFO:withlevel:Total time taken for adl-17_0 is 0:00:02.628575
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-02_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.532614
# INFO:withlevel:Total time taken for adl-02_0 is 0:00:02.564285
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-20_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.705653
# INFO:withlevel:Total time taken for adl-20_0 is 0:00:02.740714
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-24_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.494341
# INFO:withlevel:Total time taken for adl-24_0 is 0:00:02.533249
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-23_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.643616
# INFO:withlevel:Total time taken for adl-23_0 is 0:00:02.676711
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-17_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.549823
# INFO:withlevel:Total time taken for adl-17_1 is 0:00:02.585529
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-02_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.559413
# INFO:withlevel:Total time taken for adl-02_1 is 0:00:02.592484
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-20_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.556872
# INFO:withlevel:Total time taken for adl-20_1 is 0:00:02.590469
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/adl/adl-24_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.505763
# INFO:withlevel:Total time taken for adl-24_1 is 0:00:02.546707
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/fall/fall-10_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.620389
# INFO:withlevel:Total time taken for fall-10_0 is 0:00:02.655148
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/fall/fall-28_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.520491
# INFO:withlevel:Total time taken for fall-28_1 is 0:00:02.559940
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/fall/fall-28_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.613975
# INFO:withlevel:Total time taken for fall-28_0 is 0:00:02.650844
# INFO:withoutlevel:creating trajectory image at /content/trajectories/valid/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/valid/fall/fall-10_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.566233
# INFO:withlevel:Total time taken for fall-10_1 is 0:00:02.599409
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-05_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.489005
# INFO:withlevel:Total time taken for adl-05_0 is 0:00:02.527010
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-12_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.557051
# INFO:withlevel:Total time taken for adl-12_1 is 0:00:02.590221
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-07_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.568066
# INFO:withlevel:Total time taken for adl-07_0 is 0:00:02.606199
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-04_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.568740
# INFO:withlevel:Total time taken for adl-04_1 is 0:00:02.603761
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-27_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.514792
# INFO:withlevel:Total time taken for adl-27_0 is 0:00:02.547562
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-29_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.532085
# INFO:withlevel:Total time taken for adl-29_0 is 0:00:02.566856
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-14_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.499348
# INFO:withlevel:Total time taken for adl-14_0 is 0:00:02.536323
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-01_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.519709
# INFO:withlevel:Total time taken for adl-01_1 is 0:00:02.562451
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-16_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.536758
# INFO:withlevel:Total time taken for adl-16_0 is 0:00:02.572677
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-23_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.555106
# INFO:withlevel:Total time taken for adl-23_1 is 0:00:02.591793
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-16_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.523529
# INFO:withlevel:Total time taken for adl-16_1 is 0:00:02.556514
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-10_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.533115
# INFO:withlevel:Total time taken for adl-10_1 is 0:00:02.565428
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-07_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.514351
# INFO:withlevel:Total time taken for adl-07_1 is 0:00:02.548744
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-27_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.486410
# INFO:withlevel:Total time taken for adl-27_1 is 0:00:02.526071
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-14_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.505008
# INFO:withlevel:Total time taken for adl-14_1 is 0:00:02.542280
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-15_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.560946
# INFO:withlevel:Total time taken for adl-15_0 is 0:00:02.595653
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-25_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.516213
# INFO:withlevel:Total time taken for adl-25_1 is 0:00:02.552895
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-05_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.530157
# INFO:withlevel:Total time taken for adl-05_1 is 0:00:02.562878
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-08_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.537568
# INFO:withlevel:Total time taken for adl-08_1 is 0:00:02.571760
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-30_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.539744
# INFO:withlevel:Total time taken for adl-30_0 is 0:00:02.577580
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-11_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.554905
# INFO:withlevel:Total time taken for adl-11_0 is 0:00:02.593122
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-09_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.559678
# INFO:withlevel:Total time taken for adl-09_0 is 0:00:02.593588
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-25_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.579638
# INFO:withlevel:Total time taken for adl-25_0 is 0:00:02.614634
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-13_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.534589
# INFO:withlevel:Total time taken for adl-13_0 is 0:00:02.570860
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-26_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.575846
# INFO:withlevel:Total time taken for adl-26_0 is 0:00:02.611846
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-30_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.570998
# INFO:withlevel:Total time taken for adl-30_1 is 0:00:02.605484
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-01_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.507312
# INFO:withlevel:Total time taken for adl-01_0 is 0:00:02.541195
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-19_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.533334
# INFO:withlevel:Total time taken for adl-19_1 is 0:00:02.570109
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-21_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.534448
# INFO:withlevel:Total time taken for adl-21_1 is 0:00:02.567009
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-13_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.533092
# INFO:withlevel:Total time taken for adl-13_1 is 0:00:02.566832
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-04_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.616949
# INFO:withlevel:Total time taken for adl-04_0 is 0:00:02.658763
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-15_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.513074
# INFO:withlevel:Total time taken for adl-15_1 is 0:00:02.558280
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-28_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.715812
# INFO:withlevel:Total time taken for adl-28_1 is 0:00:02.748552
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-17_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.514677
# INFO:withlevel:Total time taken for adl-17_0 is 0:00:02.549381
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-18_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.514452
# INFO:withlevel:Total time taken for adl-18_1 is 0:00:02.552192
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-02_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.555097
# INFO:withlevel:Total time taken for adl-02_0 is 0:00:02.592762
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-19_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.510488
# INFO:withlevel:Total time taken for adl-19_0 is 0:00:02.542919
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-03_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.593001
# INFO:withlevel:Total time taken for adl-03_0 is 0:00:02.627890
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-18_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.503655
# INFO:withlevel:Total time taken for adl-18_0 is 0:00:02.537339
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-22_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.539321
# INFO:withlevel:Total time taken for adl-22_1 is 0:00:02.578321
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-22_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.536562
# INFO:withlevel:Total time taken for adl-22_0 is 0:00:02.568045
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-09_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.544997
# INFO:withlevel:Total time taken for adl-09_1 is 0:00:02.579896
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/adl/adl-20_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.605236
# INFO:withlevel:Total time taken for adl-20_0 is 0:00:02.647189
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/adl
# ...
# INFO:withlevel:Total time taken for fall-17_1 is 0:00:02.628730
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-27_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.622060
# INFO:withlevel:Total time taken for fall-27_0 is 0:00:02.658106
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-13_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.604217
# INFO:withlevel:Total time taken for fall-13_0 is 0:00:02.638969
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-15_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.572697
# INFO:withlevel:Total time taken for fall-15_1 is 0:00:02.606381
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-16_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.549409
# INFO:withlevel:Total time taken for fall-16_1 is 0:00:02.587033
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-23_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.608504
# INFO:withlevel:Total time taken for fall-23_1 is 0:00:02.643672
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-26_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.676661
# INFO:withlevel:Total time taken for fall-26_1 is 0:00:02.713231
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-25_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.667180
# INFO:withlevel:Total time taken for fall-25_0 is 0:00:02.707993
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-23_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.625367
# INFO:withlevel:Total time taken for fall-23_0 is 0:00:02.664540
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-28_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.547887
# INFO:withlevel:Total time taken for fall-28_0 is 0:00:02.587427
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-30_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.654428
# INFO:withlevel:Total time taken for fall-30_1 is 0:00:02.694879
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-05_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.661244
# INFO:withlevel:Total time taken for fall-05_0 is 0:00:02.701527
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-21_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.562871
# INFO:withlevel:Total time taken for fall-21_1 is 0:00:02.602170
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-04_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.656198
# INFO:withlevel:Total time taken for fall-04_1 is 0:00:02.689642
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-29_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.617453
# INFO:withlevel:Total time taken for fall-29_1 is 0:00:02.654902
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-17_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.679944
# INFO:withlevel:Total time taken for fall-17_0 is 0:00:02.717952
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-18_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.597068
# INFO:withlevel:Total time taken for fall-18_1 is 0:00:02.634026
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-03_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.587928
# INFO:withlevel:Total time taken for fall-03_1 is 0:00:02.627037
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-29_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.530026
# INFO:withlevel:Total time taken for fall-29_0 is 0:00:02.565312
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-01_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.586768
# INFO:withlevel:Total time taken for fall-01_1 is 0:00:02.622962
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-07_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.590167
# INFO:withlevel:Total time taken for fall-07_1 is 0:00:02.625405
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-07_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.610469
# INFO:withlevel:Total time taken for fall-07_0 is 0:00:02.645470
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-26_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.622196
# INFO:withlevel:Total time taken for fall-26_0 is 0:00:02.664224
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-06_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.635794
# INFO:withlevel:Total time taken for fall-06_1 is 0:00:02.677766
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-25_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.573029
# INFO:withlevel:Total time taken for fall-25_1 is 0:00:02.607397
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-27_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.614779
# INFO:withlevel:Total time taken for fall-27_1 is 0:00:02.649304
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-18_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.737404
# INFO:withlevel:Total time taken for fall-18_0 is 0:00:02.774390
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-22_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.593196
# INFO:withlevel:Total time taken for fall-22_1 is 0:00:02.639134
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-12_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.645248
# INFO:withlevel:Total time taken for fall-12_1 is 0:00:02.684705
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-11_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.646651
# INFO:withlevel:Total time taken for fall-11_0 is 0:00:02.685882
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-14_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.632238
# INFO:withlevel:Total time taken for fall-14_0 is 0:00:02.670810
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-03_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.631976
# INFO:withlevel:Total time taken for fall-03_0 is 0:00:02.670689
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-10_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.681149
# INFO:withlevel:Total time taken for fall-10_1 is 0:00:02.717050
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-09_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.572483
# INFO:withlevel:Total time taken for fall-09_1 is 0:00:02.607163
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-11_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.554418
# INFO:withlevel:Total time taken for fall-11_1 is 0:00:02.589496
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-20_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.541883
# INFO:withlevel:Total time taken for fall-20_0 is 0:00:02.577472
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-08_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.591512
# INFO:withlevel:Total time taken for fall-08_0 is 0:00:02.627774
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-02_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.522560
# INFO:withlevel:Total time taken for fall-02_1 is 0:00:02.558674
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-08_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.556527
# INFO:withlevel:Total time taken for fall-08_1 is 0:00:02.608373
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-24_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.588796
# INFO:withlevel:Total time taken for fall-24_1 is 0:00:02.622403
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-30_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.596821
# INFO:withlevel:Total time taken for fall-30_0 is 0:00:02.632295
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-01_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.569566
# INFO:withlevel:Total time taken for fall-01_0 is 0:00:02.608046
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-19_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.540514
# INFO:withlevel:Total time taken for fall-19_0 is 0:00:02.574077
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-02_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.528735
# INFO:withlevel:Total time taken for fall-02_0 is 0:00:02.565587
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-05_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.572557
# INFO:withlevel:Total time taken for fall-05_1 is 0:00:02.610163
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-19_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.535921
# INFO:withlevel:Total time taken for fall-19_1 is 0:00:02.571345
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-14_1 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.553714
# INFO:withlevel:Total time taken for fall-14_1 is 0:00:02.588310
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-04_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.496583
# INFO:withlevel:Total time taken for fall-04_0 is 0:00:02.531002
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-12_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.559301
# INFO:withlevel:Total time taken for fall-12_0 is 0:00:02.593006
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-21_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.525999
# INFO:withlevel:Total time taken for fall-21_0 is 0:00:02.564564
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-15_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.616475
# INFO:withlevel:Total time taken for fall-15_0 is 0:00:02.651281
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-16_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.649707
# INFO:withlevel:Total time taken for fall-16_0 is 0:00:02.690031
# INFO:withoutlevel:creating trajectory image at /content/trajectories/test/fall
# INFO:withoutlevel:Working on creating ... /content/boundingBox/test/fall/fall-09_0 set
# INFO:withlevel:Elapsed time for Bounding box calculation is 0:00:02.551644
# INFO:withlevel:Total time taken for fall-09_0 is 0:00:02.590475
# INFO:withlevel:Total time taken to create trajectory images: 0:12:12.504804

# %% [markdown]
# ## Artifact

# %%
bbox = wandb.Artifact('boundingBox', type='dataset')
bbox.add_dir('boundingBox')
wandb.log_artifact(bbox)
# Out:
# wandb: Adding directory to artifact (./boundingBox)... Done. 13.5s

# %%
trajectory = wandb.Artifact('trajectory', type='dataset')
trajectory.add_dir('trajectories')
wandb.log_artifact(trajectory)
# Out:
# wandb: Adding directory to artifact (./trajectories)... Done. 0.5s

# %% [markdown]
# ## Data Generators

# %%
logger_t.info(f'{"="*100} \n\nSTEP 5: Create Data generators\n')
datagen = tf.keras.preprocessing.image.ImageDataGenerator()
logger.info(f'batch size: {cfg.batch_size}')
root = os.getcwd()
train = datagen.flow_from_directory(root + '/trajectories/train',target_size=(224, 224),color_mode='grayscale',batch_size=cfg.batch_size)
valid = datagen.flow_from_directory(root + '/trajectories/valid',target_size=(224, 224),color_mode='grayscale',batch_size=cfg.batch_size)
test = datagen.flow_from_directory(root + '/trajectories/test',target_size=(224, 224),color_mode='grayscale',batch_size=cfg.batch_size)
# Out:
# INFO:withoutlevel:====================================================================================================
#
# STEP 5: Create Data generators
#
# INFO:withlevel:batch size: 32
# Found 96 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %% [markdown]
# ## Model

# %%
from tensorflow.keras.layers import Conv2D,MaxPool2D,GlobalAveragePooling2D,Dense,Dropout
from tensorflow.keras.metrics import Precision, Recall
from wandb.keras import WandbCallback
logger_t.info(f'{"="*100} \n\nSTEP 5: Create Model and train the model\n')



model = tf.keras.Sequential([
              tf.keras.Input(shape=(224,224,1)),
              Conv2D(32,3,strides=2,padding='same',activation=cfg.activation,use_bias=False),
              MaxPool2D(),
              Conv2D(64,3,strides=2,padding='same',activation=cfg.activation,use_bias=False),
              MaxPool2D(),
              Conv2D(128,3,strides=2,padding='same',activation=cfg.activation,use_bias=False),
              MaxPool2D(),
              GlobalAveragePooling2D(),
              Dense(128),
              Dropout(cfg.dropout_rate),
              Dense(64),
              Dropout(cfg.dropout_rate),
              Dense(2,activation='sigmoid')])


model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-3), 
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy', Precision(), Recall()])
logger.info(f'{model.summary()}')
# Out:
# INFO:withoutlevel:====================================================================================================
#
# STEP 5: Create Model and train the model
#
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# INFO:withlevel:None
# Model: "sequential_234"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 112, 112, 32)      288
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        18432
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         73728
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 117,346
# Trainable params: 117,346
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
# fit model
history = model.fit_generator(generator=train,
                              validation_data=valid,
                              epochs=cfg.epochs,
                              verbose=1,
                              callbacks = [WandbCallback()])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/15
# 3/3 [==============================] - 4s 599ms/step - loss: 2.3626 - accuracy: 0.5729 - precision: 0.5612 - recall: 0.5729 - val_loss: 0.4090 - val_accuracy: 0.9444 - val_precision: 0.7826 - val_recall: 1.0000
# Epoch 2/15
# 3/3 [==============================] - 1s 376ms/step - loss: 1.1731 - accuracy: 0.6667 - precision: 0.5982 - recall: 0.6979 - val_loss: 0.3090 - val_accuracy: 0.8889 - val_precision: 0.9333 - val_recall: 0.7778
# Epoch 3/15
# 3/3 [==============================] - 1s 370ms/step - loss: 0.6305 - accuracy: 0.8542 - precision: 0.8125 - recall: 0.6771 - val_loss: 0.5805 - val_accuracy: 0.7222 - val_precision: 0.7500 - val_recall: 0.6667
# Epoch 4/15
# 3/3 [==============================] - 1s 362ms/step - loss: 0.5083 - accuracy: 0.8646 - precision: 0.7978 - recall: 0.7396 - val_loss: 0.3383 - val_accuracy: 0.8889 - val_precision: 0.8000 - val_recall: 0.8889
# Epoch 5/15
# 3/3 [==============================] - 1s 375ms/step - loss: 0.4470 - accuracy: 0.8958 - precision: 0.7699 - recall: 0.9062 - val_loss: 0.1329 - val_accuracy: 0.9444 - val_precision: 0.9444 - val_recall: 0.9444
# Epoch 6/15
# 3/3 [==============================] - 1s 383ms/step - loss: 0.3347 - accuracy: 0.8958 - precision: 0.7963 - recall: 0.8958 - val_loss: 0.1729 - val_accuracy: 0.9444 - val_precision: 0.9412 - val_recall: 0.8889
# Epoch 7/15
# 3/3 [==============================] - 1s 362ms/step - loss: 0.1646 - accuracy: 0.9688 - precision: 0.9457 - recall: 0.9062 - val_loss: 0.3736 - val_accuracy: 0.8333 - val_precision: 0.8750 - val_recall: 0.7778
# Epoch 8/15
# 3/3 [==============================] - 1s 378ms/step - loss: 0.1989 - accuracy: 0.9167 - precision: 0.9053 - recall: 0.8958 - val_loss: 0.4019 - val_accuracy: 0.7778 - val_precision: 0.8750 - val_recall: 0.7778
# Epoch 9/15
# 3/3 [==============================] - 1s 376ms/step - loss: 0.1647 - accuracy: 0.9479 - precision: 0.9375 - recall: 0.9375 - val_loss: 0.2086 - val_accuracy: 0.9444 - val_precision: 0.9375 - val_recall: 0.8333
# Epoch 10/15
# 3/3 [==============================] - 1s 369ms/step - loss: 0.1176 - accuracy: 0.9896 - precision: 0.9485 - recall: 0.9583 - val_loss: 0.0881 - val_accuracy: 0.9444 - val_precision: 0.9444 - val_recall: 0.9444
# Epoch 11/15
# 3/3 [==============================] - 1s 371ms/step - loss: 0.0890 - accuracy: 0.9896 - precision: 0.9681 - recall: 0.9479 - val_loss: 0.0443 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 12/15
# 3/3 [==============================] - 1s 370ms/step - loss: 0.0798 - accuracy: 0.9896 - precision: 0.9694 - recall: 0.9896 - val_loss: 0.0284 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 13/15
# 3/3 [==============================] - 1s 377ms/step - loss: 0.0574 - accuracy: 1.0000 - precision: 0.9896 - recall: 0.9896 - val_loss: 0.0394 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 14/15
# 3/3 [==============================] - 1s 377ms/step - loss: 0.0482 - accuracy: 1.0000 - precision: 0.9794 - recall: 0.9896 - val_loss: 0.0883 - val_accuracy: 0.9444 - val_precision: 0.9444 - val_recall: 0.9444
# Epoch 15/15
# 3/3 [==============================] - 1s 395ms/step - loss: 0.0599 - accuracy: 0.9792 - precision: 0.9894 - recall: 0.9688 - val_loss: 0.1081 - val_accuracy: 0.9444 - val_precision: 0.9444 - val_recall: 0.9444

# %%
best_model = wandb.restore("model-best.h5")
model.load_weights(best_model.name)

# %%
results = model.evaluate(test)
# Out:
# 4/4 [==============================] - 0s 95ms/step - loss: 0.0979 - accuracy: 0.9583 - precision: 0.9576 - recall: 0.9417

# %%
wandb.summary['test_loss'] = results[0]
wandb.summary['test_accuracy'] = results[1]
wandb.summary['test_precision'] = results[2]
wandb.summary['test_recall'] = results[3]

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 136<br/>Program ended successfully.
# VBox(children=(Label(value=' 260.48MB of 260.48MB uploaded (259.08MB deduped)\r'), FloatProgress(value=1.0, ma…
# Find user logs for this run at: <code>/content/wandb/run-20210729_133600-1fre7iiu/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210729_133600-1fre7iiu/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>1285</td></tr><tr><td>_timestamp</td><td>1627567046</td></tr><tr><td>_step</td><td>554</td></tr><tr><td>Download_TotalTime</td><td>404.57377</td></tr><tr><td>ModifyFileNames_totaltime</td><td>56.73974</td></tr><tr><td>trainset_size</td><td>48</td></tr><tr><td>validationset_size</td><td>9</td></tr><tr><td>testset_size</td><td>3</td></tr><tr><td>trainSubset_creationTime</td><td>17.83273</td></tr><tr><td>valSubset_creationTime</td><td>3.20152</td></tr><tr><td>testSubset_creationTime</td><td>27.45594</td></tr><tr><td>Trajectory_totaltime</td><td>732.51052</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.05986</td></tr><tr><td>accuracy</td><td>0.97917</td></tr><tr><td>precision</td><td>0.98936</td></tr><tr><td>recall</td><td>0.96875</td></tr><tr><td>val_loss</td><td>0.10813</td></tr><tr><td>val_accuracy</td><td>0.94444</td></tr><tr><td>val_precision</td><td>0.94444</td></tr><tr><td>val_recall</td><td>0.94444</td></tr><tr><td>best_val_loss</td><td>0.0284</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>test_loss</td><td>0.09792</td></tr><tr><td>test_accuracy</td><td>0.95833</td></tr><tr><td>test_precision</td><td>0.95763</td></tr><tr><td>test_recall</td><td>0.94167</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁▁▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>accuracy</td><td>▁▃▆▆▆▆▇▇▇██████</td></tr><tr><td>precision</td><td>▁▂▅▅▄▅▇▇▇▇█████</td></tr><tr><td>recall</td><td>▁▃▃▄▇▆▇▆▇▇▇████</td></tr><tr><td>val_loss</td><td>▆▅█▅▂▃▅▆▃▂▁▁▁▂▂</td></tr><tr><td>val_accuracy</td><td>▇▅▁▅▇▇▄▂▇▇███▇▇</td></tr><tr><td>val_precision</td><td>▂▆▁▂▆▆▅▅▆▆███▆▆</td></tr><tr><td>val_recall</td><td>█▃▁▆▇▆▃▃▄▇███▇▇</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 5770 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">rural-resonance-27</strong>: <a href="https://wandb.ai/manikandan/fall_detection/runs/1fre7iiu" target="_blank">https://wandb.ai/manikandan/fall_detection/runs/1fre7iiu</a><br/>
